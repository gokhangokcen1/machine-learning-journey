# %%
import pandas as pd 
import numpy as np

# %%
data = np.array([[1,4], [2,5], [3,6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
df = pd.DataFrame(data, index=["row1", "row2", "row3"], columns= ["col1", "col2"])
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
sehirler = ["Isparta", "Antalya", "Ankara", "Burdur"]
nufus = ["1", "2", "3", "4"]
dict_states = {"Sehirler":sehirler, "Nufus":nufus}
df_nufus = pd.DataFrame(dict_states)
df_nufus
# Out:
#   Sehirler Nufus
# 0  Isparta     1
# 1  Antalya     2
# 2   Ankara     3
# 3   Burdur     4

# %%
# pd.read_csv()

# %%
df_exams = pd.read_csv("StudentsPerformance.csv")
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df_exams["gender"]
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
df_exams[["gender", "math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # Sütun ekleme

# %%
df_exams["language score"] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %%
language_score = np.arange(0,1000)
len(language_score)
# Out:
# 1000

# %%
df_exams["language score"] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
int_language_score = np.random.randint(1,100, size=1000)
print(min(int_language_score))
print(max(int_language_score))
# Out:
# 1
# 99

# %%
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                38
# 1                 2
# 2                39
# 3                88
# 4                21
# ..              ...
# 995              15
# 996              90
# 997              73
# 998              13
# 999               9
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## assign

# %%
score1 = np.random.randint(1,100, size=1000)
score2 = np.random.randint(1,100, size=1000)
score2
# Out:
# array([99, 22, 64, 97, 59, 81, 33, 14, 33, 76, 98, 53, 31, 66,  6, 55, 57,
#         1, 76, 85, 68, 91, 76, 52, 55, 99, 96, 58, 17, 59, 94, 77,  4, 34,
#        54, 83, 47, 77, 65, 79, 23, 99,  4, 10, 85, 39, 29, 81,  4, 56, 77,
#        49, 73, 78, 99, 68, 42, 48, 77, 71, 16, 82, 38, 78,  7, 99, 14, 44,
#        61, 72, 18, 29, 99, 92, 14, 20, 98,  3, 80, 13, 10, 44, 71, 97, 81,
#         5, 73, 54, 22, 31, 60, 67, 34, 81, 58, 98,  4,  8, 15, 85, 10, 47,
#        81, 71, 59, 30, 45, 11, 23, 57, 88, 26, 50, 75, 47, 63, 31,  7, 76,
#        44, 97, 13, 14, 74, 36, 20, 48, 23, 32, 84, 84, 12, 98, 29,  4, 75,
#        11, 34, 18, 51, 44, 84, 54, 93, 50, 93, 83, 27, 39, 83, 81,  4, 21,
#        32, 55, 52, 21, 21, 14, 59, 19, 39, 62, 77,  4, 25, 87, 77, 94, 71,
#        85, 81, 70, 19, 37, 33, 47, 86, 62, 60, 37, 25, 83, 50, 67, 53, 62,
#        91, 19, 32, 98, 73, 31, 26, 35, 90, 11, 82, 43, 15, 64, 25, 90,  3,
#         1,  2, 44, 96,  4, 91, 96, 57,  9, 17, 60, 57, 91, 49, 95, 54, 11,
#         8, 98, 76, 50, 50, 70, 95, 56, 79, 98, 63, 54, 62, 59,  4, 17, 96,
#        90, 64, 66, 96, 95, 41, 74,  8, 10, 53,  9, 39, 98, 95, 37, 80, 40,
#        85,  7, 59, 69, 62, 20, 50,  1, 75, 52, 65, 91, 35, 96, 82, 45, 27,
#        80, 55, 27, 47, 43, 48, 81, 52, 55, 95, 88, 45, 97, 36, 83, 93,  6,
#        41, 58, 88, 28, 68, 63, 24, 35, 80, 36, 29, 53, 24, 89, 62, 71, 84,
#         5, 59, 23,  6,  8, 56, 93, 44, 39,  3, 98, 13, 52, 51, 23, 41, 41,
#        73, 17, 51, 99, 69, 58, 44, 83, 30,  5, 61, 45, 81, 81, 30, 42, 30,
#        35, 66, 19,  8, 98, 41,  9, 47, 37, 17, 17, 95, 48, 87, 68, 50, 12,
#        41, 18, 76, 24, 47, 91, 78, 25, 64, 41, 41, 81, 76, 69, 38, 65, 84,
#        41, 96, 36,  4, 82, 62,  8, 90, 10, 81, 70,  1, 94, 56, 74, 26, 92,
#        41, 85, 60, 28, 54, 48, 55, 24, 97, 22, 47, 50, 26,  7, 52, 28, 89,
#        47, 78, 72, 81, 84, 58, 43, 80, 90, 60, 55, 22, 95, 75, 43, 39, 80,
#        72, 68,  3, 75, 97, 55, 44, 98, 91, 13, 91, 36, 28, 32, 84, 10, 71,
#        11, 68,  7, 52, 55, 39, 99, 65, 60, 57, 71, 86, 65, 16,  1, 66, 35,
#        12, 42, 30, 36, 31, 78, 14, 40,  7, 91, 12, 89, 92, 73, 22, 74, 98,
#        93, 36, 37, 62, 32, 43, 49, 74, 12, 60, 22, 44, 61, 29],
#       dtype=int32)

# %%
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))
series2
# Out:
# 0      99
# 1      22
# 2      64
# 3      97
# 4      59
#        ..
# 995    60
# 996    22
# 997    44
# 998    61
# 999    29
# Length: 1000, dtype: int32

# %%
df_exams = df_exams.assign(score1=series1, score2=series2)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                38      83      99
# 1                 2      22      22
# 2                39      92      64
# 3                88      25      97
# 4                21      19      59
# ..              ...     ...     ...
# 995              15      14      60
# 996              90      61      22
# 997              73      63      44
# 998              13       6      61
# 999               9      60      29
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## insert
# Hangi sırada olacağını belirtebiliyorsun

# %%
df_exams.insert(1, "test", series1)
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    83        group B           bachelor's degree      standard
# 1    female    22        group C                some college      standard
# 2    female    92        group B             master's degree      standard
# 3      male    25        group A          associate's degree  free/reduced
# 4      male    19        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    14        group E             master's degree      standard
# 996    male    61        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female     6        group D                some college      standard
# 999  female    60        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                38      83      99
# 1                 2      22      22
# 2                39      92      64
# 3                88      25      97
# 4                21      19      59
# ..              ...     ...     ...
# 995              15      14      60
# 996              90      61      22
# 997              73      63      44
# 998              13       6      61
# 999               9      60      29
#
# [1000 rows x 12 columns]

# %%
df_exams["math score"].sum()
# Out:
# np.int64(66089)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    83        group B           bachelor's degree      standard
# 1    female    22        group C                some college      standard
# 2    female    92        group B             master's degree      standard
# 3      male    25        group A          associate's degree  free/reduced
# 4      male    19        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    14        group E             master's degree      standard
# 996    male    61        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female     6        group D                some college      standard
# 999  female    60        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                38      83      99
# 1                 2      22      22
# 2                39      92      64
# 3                88      25      97
# 4                21      19      59
# ..              ...     ...     ...
# 995              15      14      60
# 996              90      61      22
# 997              73      63      44
# 998              13       6      61
# 999               9      60      29
#
# [1000 rows x 12 columns]

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    83        group B           bachelor's degree      standard
# 1    female    22        group C                some college      standard
# 2    female    92        group B             master's degree      standard
# 3      male    25        group A          associate's degree  free/reduced
# 4      male    19        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    14        group E             master's degree      standard
# 996    male    61        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female     6        group D                some college      standard
# 999  female    60        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                38      83      99
# 1                 2      22      22
# 2                39      92      64
# 3                88      25      97
# 4                21      19      59
# ..              ...     ...     ...
# 995              15      14      60
# 996              90      61      22
# 997              73      63      44
# 998              13       6      61
# 999               9      60      29
#
# [1000 rows x 12 columns]

# %%
df_exams["average"] = (df_exams["math score"] + df_exams["reading score"] + df_exams["writing score"]) / 3
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    83        group B           bachelor's degree      standard
# 1    female    22        group C                some college      standard
# 2    female    92        group B             master's degree      standard
# 3      male    25        group A          associate's degree  free/reduced
# 4      male    19        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    14        group E             master's degree      standard
# 996    male    61        group C                 high school  free/reduced
# 997  female    63        group C                 high school  free/reduced
# 998  female     6        group D                some college      standard
# 999  female    60        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2    average
# 0                38      83      99  72.666667
# 1                 2      22      22  82.333333
# 2                39      92      64  92.666667
# 3                88      25      97  49.333333
# 4                21      19      59  76.333333
# ..              ...     ...     ...        ...
# 995              15      14      60  94.000000
# 996              90      61      22  57.333333
# 997              73      63      44  65.000000
# 998              13       6      61  74.333333
# 999               9      60      29  83.000000
#
# [1000 rows x 13 columns]

# %% [markdown]
# # değer sayıları

# %%
df_exams["gender"].count()
# Out:
# np.int64(1000)

# %%
df_exams["gender"].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df_exams["gender"].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df_exams['parental level of education'].value_counts(normalize=True)
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %% [markdown]
# # sıralama

# %%
df_exams.sort_values("math score", ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 962  female    30        group E          associate's degree      standard
# 625    male    61        group D                some college      standard
# 458  female    57        group E           bachelor's degree      standard
# 623    male     7        group A                some college      standard
# 451  female    69        group E                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    44        group C                some college  free/reduced
# 787  female    54        group B                some college      standard
# 17   female    11        group B            some high school  free/reduced
# 980  female    84        group B                 high school  free/reduced
# 59   female    84        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 962              46      30      71  100.000000
# 625              43      61      67   98.666667
# 458              34      57      88  100.000000
# 623              38       7      58   94.000000
# 451               3      69      72   96.333333
# ..              ...     ...     ...         ...
# 145              38      44      93   31.333333
# 787              96      54      48   29.666667
# 17               42      11       1   26.000000
# 980              82      84      89   18.333333
# 59               46      84      71    9.000000
#
# [1000 rows x 13 columns]

# %%
df_exams.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    38        group E          associate's degree  free/reduced
# 458  female    57        group E           bachelor's degree      standard
# 916    male    92        group E           bachelor's degree      standard
# 962  female    30        group E          associate's degree      standard
# 625    male    61        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    44        group C                some college  free/reduced
# 787  female    54        group B                some college      standard
# 17   female    11        group B            some high school  free/reduced
# 980  female    84        group B                 high school  free/reduced
# 59   female    84        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 149              46      38      83   97.666667
# 458              34      57      88  100.000000
# 916              29      92      28  100.000000
# 962              46      30      71  100.000000
# 625              43      61      67   98.666667
# ..              ...     ...     ...         ...
# 145              38      44      93   31.333333
# 787              96      54      48   29.666667
# 17               42      11       1   26.000000
# 980              82      84      89   18.333333
# 59               46      84      71    9.000000
#
# [1000 rows x 13 columns]

# %% [markdown]
# # index değiştirme

# %% [raw]
# new_index = np.arange(0, 1000)
# random.shuffle(new_index)
# df_exams['new_index'] = new_index
# df_exams.set_index('new_index', inplace=True)
#
# SORT INDEX
# df_exams.sort_index()

# %% [markdown]
# # SÜTUN İSİMLERİ DEĞİŞTİRME

# %%
df_exams = df_exams.rename(columns={"gender":"Gender"})
df_exams.head()
# Out:
#    Gender  test race/ethnicity parental level of education         lunch  \
# 0  female    83        group B           bachelor's degree      standard
# 1  female    22        group C                some college      standard
# 2  female    92        group B             master's degree      standard
# 3    male    25        group A          associate's degree  free/reduced
# 4    male    19        group C                some college      standard
#
#   test preparation course  MS  RS  WS  language score  score1  score2  \
# 0                    none  72  72  74              38      83      99
# 1               completed  69  90  88               2      22      22
# 2                    none  90  95  93              39      92      64
# 3                    none  47  57  44              88      25      97
# 4                    none  76  78  75              21      19      59
#
#      average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %%
df_exams.rename(columns={'math score':'MS', 'reading score':'RS', 'writing score':'WS'}, inplace=True)
df_exams.head()
# Out:
#    Gender  test race/ethnicity parental level of education         lunch  \
# 0  female    83        group B           bachelor's degree      standard
# 1  female    22        group C                some college      standard
# 2  female    92        group B             master's degree      standard
# 3    male    25        group A          associate's degree  free/reduced
# 4    male    19        group C                some college      standard
#
#   test preparation course  MS  RS  WS  language score  score1  score2  \
# 0                    none  72  72  74              38      83      99
# 1               completed  69  90  88               2      22      22
# 2                    none  90  95  93              39      92      64
# 3                    none  47  57  44              88      25      97
# 4                    none  76  78  75              21      19      59
#
#      average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %% [markdown]
# # INDEX İSİM DEĞİŞTİRME

# %%
df_exams.rename(index={0:"A", 1:"B", 2:"C"}, inplace=True)
df_exams.head(3)
# Out:
#    Gender  test race/ethnicity parental level of education     lunch  \
# A  female    83        group B           bachelor's degree  standard
# B  female    22        group C                some college  standard
# C  female    92        group B             master's degree  standard
#
#   test preparation course  MS  RS  WS  language score  score1  score2  \
# A                    none  72  72  74              38      83      99
# B               completed  69  90  88               2      22      22
# C                    none  90  95  93              39      92      64
#
#      average
# A  72.666667
# B  82.333333
# C  92.666667
